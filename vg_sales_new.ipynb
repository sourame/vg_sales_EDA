# %% [markdown]
# Phase 2 [EDL - Data analysis phase ]

# %% [markdown]
# 1. Open new Jupyter notebook
# 2. Import required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 3. Read your cleaned csv which you did in phase 1

# %%
vg_sales_df = pd.read_csv('./vg_sales_new.csv')
vg_sales_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16411  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16412               LMA Manager 2007     X360           2006.0        Sports
# 16413        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16414               Spirits & Spells      GBA           2003.0      Platform
# 16415            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# 4. Shape the data

# %%
vg_sales_df.shape
# Out:
# (16416, 10)

# %% [markdown]
# 5. Show first five records

# %%
vg_sales_df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.36     28.96      3.77         8.45         82.53
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.68     12.76      3.79         3.29         35.52
# 3     15.61     10.93      3.28         2.95         32.77
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# 6. Show all columns of the dataframe

# %%
vg_sales_df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# 7. Show last 5 five rows

# %%
vg_sales_df.tail(5)
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16411  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16412               LMA Manager 2007     X360           2006.0      Sports
# 16413        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16414               Spirits & Spells      GBA           2003.0    Platform
# 16415            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 16411    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16412   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16413  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16414       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16415    Tecmo Koei      0.00      0.00      0.01          0.0          0.01

# %% [markdown]
# 8. Describe the data.

# %%
vg_sales_df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16416.000000  16416.000000  16416.000000  16416.000000
# mean       2006.489888      0.264129      0.146034      0.078623
# std           5.881148      0.819028      0.507134      0.311348
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales
# count  16416.000000  16416.000000
# mean       0.047670      0.536708
# std        0.188156      1.559885
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.030000      0.470000
# max       10.570000     82.530000

# %% [markdown]
# 9. Group the sales data of each region on Year_of_Release and plot the same (It should show which region sales was at peak on which year of release)

# %%
numeric_col_df = vg_sales_df[['Year_of_Release','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']]
sales_by_reg = numeric_col_df.iloc[:,:-1].groupby(['Year_of_Release']).sum()
sales_by_reg.reset_index(inplace=True)
sales_by_reg
# Out:
#     Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0            1980.0     10.59      0.67      0.00         0.12
# 1            1981.0     33.40      1.96      0.00         0.32
# 2            1982.0     26.92      1.65      0.00         0.31
# 3            1983.0      7.76      0.80      8.10         0.14
# 4            1984.0     33.28      2.10     14.27         0.70
# 5            1985.0     33.73      4.74     14.56         0.92
# 6            1986.0     12.50      2.84     19.81         1.93
# 7            1987.0      8.46      1.41     11.63         0.20
# 8            1988.0     23.87      6.59     15.76         0.99
# 9            1989.0     45.15      8.44     18.36         1.50
# 10           1990.0     25.46      7.63     14.88         1.40
# 11           1991.0     12.76      3.95     14.78         0.74
# 12           1992.0     33.89     11.71     28.91         1.65
# 13           1993.0     15.12      4.65     25.33         0.89
# ...

# %%
#sales_by_reg.plot(x='Year_of_Release',y=['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales'],kind="line")
sales_reg_df = sales_by_reg.melt('Year_of_Release', var_name='Region', value_name='Sales')
plt.figure(figsize=(25,10))
sns.catplot(x="Year_of_Release",y="Sales", hue='Region', 
            data=sales_reg_df, kind='point',height=5, aspect=2)
plt.xticks(rotation=90, fontsize=9)
plt.title("Sales per Region by Year of Release")
# Out:
# Text(0.5, 1.0, 'Sales per Region by Year of Release')

# %% [markdown]
# 10. Group North American, Japan, European & Other region sales data as per Genre and plot it (It should show highest of region according to game category , ex- NA_Sales is highest in Adventure category , plot kind should be bar)

# %%
genre_df = vg_sales_df[['Genre','NA_Sales','EU_Sales','JP_Sales','Other_Sales']]
sales_by_genre = genre_df.groupby(['Genre']).max()
sales_by_genre.reset_index(inplace=True)
sales_by_genre
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0         Action      9.66      9.09      3.96        10.57
# 1      Adventure      6.16      2.79      2.69         0.82
# 2       Fighting      6.62      2.55      2.87         1.41
# 3           Misc     15.00      9.20      4.16         2.84
# 4       Platform     29.08      9.14      6.81         2.88
# 5         Puzzle     23.20      5.35      5.32         1.18
# 6         Racing     15.68     12.76      4.13         7.53
# 7   Role-Playing     11.27      8.89     10.22         1.74
# 8        Shooter     26.93      5.86      1.46         2.42
# 9     Simulation      9.05     10.95      5.33         2.74
# 10        Sports     41.36     28.96      3.77         8.45
# 11      Strategy      3.18      2.27      1.61         0.58

# %%
#sales_genre_df = pd.melt(sales_by_genre,id_vars=['Genre'],value_vars=['NA_Sales','EU_sales','JP_Sales','Other_Sales','Global_Sales'])
sales_genre_df = sales_by_genre.melt('Genre', var_name='Region', value_name='Sales')
plt.figure(figsize=(6,10))
sns.set(rc={"font.style":"normal",
            "axes.facecolor":(0.9, 0.9, 0.9),
            "figure.facecolor":'white',
            'axes.labelsize':12,
            'xtick.labelsize':8,
            'ytick.labelsize':8})
sns.catplot(x="Sales",y="Genre", hue='Region', 
            data=sales_genre_df, kind='bar')
plt.title("Sales per Region by Genre")
# Out:
# Text(0.5, 1.0, 'Sales per Region by Genre')

# %% [markdown]
# 11. Group North American, Japan, European & Other region sales data as per Platform and plot it (Should show sales as per "Platform genre" , plot kind should be bar )

# %%
pltfm_df = vg_sales_df[['Platform','NA_Sales','EU_Sales','JP_Sales','Other_Sales']]
sales_by_pltfm = pltfm_df.groupby(['Platform']).max()
sales_by_pltfm.reset_index(inplace=True)  #sum()
sales_pltfm_df = sales_by_pltfm.melt('Platform', var_name='Region', value_name='Total_Sales')

# %%
plt.figure(figsize=(25,10))
sns.catplot(x="Platform", y="Total_Sales", hue='Region', data=sales_pltfm_df, kind='bar',height=5, aspect=2)
plt.xticks(rotation=30, fontsize=9)
plt.show()

# %% [markdown]
# 12. Plot the Sales in all regions as per Platform , you need to create a boxplot for that which will show the distribution of sales as per platform

# %%
plt.figure(figsize=(18,40))
plt.title("Global Sales of Video Games by Platform")

#sns.boxplot(data=vg_sales_df,y='Global_Sales', x="Platform",order=vg_sales_df.groupby('Platform', sort=False)['Global_Sales'].max().index)
sns.boxplot(data=vg_sales_df,x='Global_Sales', y="Platform",hue='Platform',orient='h',dodge=False)
# Out:
# <AxesSubplot: title={'center': 'Global Sales of Video Games by Platform'}, xlabel='Global_Sales', ylabel='Platform'>

# %% [markdown]
# 13. Find out which Genre games are sold in highest numbers (create a countplot of seaborn which could do that)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Genre',data=vg_sales_df)
plt.xticks(rotation=30, fontsize=9)
plt.show()

# %% [markdown]
# 14. Try to find out global sales as per Genre ,(create a barplot of seaborn for that)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Genre',y='Global_Sales',data=vg_sales_df)
plt.xticks(rotation=30, fontsize=9)
plt.show()

# %% [markdown]
# Additional points:

# %% [markdown]
# 1. How many video games have been released for each platform?

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Platform',data=vg_sales_df,order=vg_sales_df.Platform.value_counts().index)
plt.xticks(rotation=30, fontsize=9)
plt.show()

# %% [markdown]
# 2. Global Sales by Platform

# %%
plt.figure(figsize=(12,8))
plt.title("Total of Global Sales of Video Games by Platform")
sns.barplot(data=vg_sales_df.groupby('Platform', as_index=False).sum(), 
            x='Global_Sales', y='Platform', 
            order=vg_sales_df.groupby('Platform', as_index=False).sum()
                .sort_values('Global_Sales', ascending=False).Platform)
# Out:
# <AxesSubplot:title={'center':'Total of Global Sales of Video Games by Platform'}, xlabel='Global_Sales', ylabel='Platform'>

# %% [markdown]
# How many video games of each genre are there in the dataset?

# %%
plt.figure(figsize=(12,6))
plt.title("Count of Video Games by Genre")
sns.countplot(x='Genre', data=vg_sales_df, order=vg_sales_df.Genre.value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Count of Video Games by Genre'}, xlabel='Genre', ylabel='count'>

# %% [markdown]
# Global sales by genre

# %%
plt.figure(figsize=(12,6))
plt.title("Total Global Sales of Video Games by Genre")
sns.barplot(data=vg_sales_df.groupby('Genre', as_index=False).sum(), y='Global_Sales', x='Genre', 
            order=vg_sales_df.groupby('Genre', as_index=False).sum().sort_values('Global_Sales', ascending=False).Genre)
# Out:
# <AxesSubplot:title={'center':'Total Global Sales of Video Games by Genre'}, xlabel='Genre', ylabel='Global_Sales'>

# %% [markdown]
# Top 10 publishers

# %%
plt.figure(figsize=(12,5))
plt.title("Count of Top 10 Publishers")
sns.countplot(x='Publisher', data=vg_sales_df, order=vg_sales_df.Publisher.value_counts().index[:10])
# Out:
# <AxesSubplot:title={'center':'Count of Top 10 Publishers'}, xlabel='Publisher', ylabel='count'>

# %% [markdown]
# What are the Top 10 Publishers for Global_Sales in general?

# %%
top_10_pub = vg_sales_df.groupby("Publisher").sum()[["Global_Sales"]].sort_values(['Global_Sales'],ascending=False).head(10)
plt.figure(figsize=(12,5))
ax = sns.scatterplot(
    data = top_10_pub.reset_index(),
    x= 'Publisher',
    y = 'Global_Sales',
    hue= 'Publisher'    
)
ax.set(xlabel='Top 10 Publishers', ylabel='Gobal Sales')
plt.xticks(rotation=90)
plt.show()
# vg_sales_df.groupby("Publisher")["Global_Sales"].sum().sort_values(ascending=False).head(10).plot.bar(figsize=(15, 5),ylabel="Global Sales in millions of copies")
