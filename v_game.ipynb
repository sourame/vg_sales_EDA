# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
v_game_df = pd.read_csv('./Video_Games_Sales_as_at_22_Dec_2016.csv')
v_game_df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
v_game_df.shape
v_game_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
v_game_df.notna()
# Out:
#        Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      True      True             True   True       True      True      True
# 1      True      True             True   True       True      True      True
# 2      True      True             True   True       True      True      True
# 3      True      True             True   True       True      True      True
# 4      True      True             True   True       True      True      True
# ...     ...       ...              ...    ...        ...       ...       ...
# 16714  True      True             True   True       True      True      True
# 16715  True      True             True   True       True      True      True
# 16716  True      True             True   True       True      True      True
# 16717  True      True             True   True       True      True      True
# 16718  True      True             True   True       True      True      True
#
# ...

# %%
v_game_df.isna().sum().sort_values(ascending=False)
# Out:
# User_Score         9129
# User_Count         9129
# Critic_Score       8582
# Critic_Count       8582
# Rating             6769
# Developer          6623
# Year_of_Release     269
# Publisher            54
# Name                  2
# Genre                 2
# Platform              0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# dtype: int64

# %%
null_df = v_game_df.isna()
null_df
# Out:
#         Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False     False            False  False      False     False     False
# 1      False     False            False  False      False     False     False
# 2      False     False            False  False      False     False     False
# 3      False     False            False  False      False     False     False
# 4      False     False            False  False      False     False     False
# ...      ...       ...              ...    ...        ...       ...       ...
# 16714  False     False            False  False      False     False     False
# 16715  False     False            False  False      False     False     False
# 16716  False     False            False  False      False     False     False
# 16717  False     False            False  False      False     False     False
# 16718  False     False            False  False      False     False     False
#
# ...

# %% [markdown]
# isna() - false for non null values. Heatmap shows the value 1 for null values. [for eg: year of release has some null values, columns from critic_score to rating have lot of null values.]

# %%
plt.figure(figsize=(10,7))
sns.heatmap(null_df,cbar=True)
# sns.heatmap(null_df,annot=True,linewidths=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 7. Drop outliers (columns which are not useful according to you)

# %%
outliers = ['Critic_Score','Critic_Count','User_Score','User_Count','Developer','Rating']
vg_new_df = v_game_df.drop(outliers,axis=1)

# %% [markdown]
# Columns in outliers have numerous Null values

# %%
vg_new_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# 8. Drop the null values containing rows from the object which you created in point 7

# %%
vg_new_df.dropna(inplace=True)
vg_new_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# 10. Export dataframe to your desired location with no index column

# %%
vg_new_df.to_csv('vg_sales_new.csv',index=False)
